# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
from pymongo import MongoClient
from ipywidgets import interact, widgets
import datetime

# Import collection from MongoDB database
client = MongoClient('localhost', 27017) 
db = client.fridge_fills
collection = db.fridgefills

cursor = collection.find({})

data = list(cursor)

df_dates = pd.DataFrame(data)

df_dates.drop('_id', axis=1, inplace=True)

df_dates.head()
# Out:
#        Date Day of Week         Time of Day              Name  \
# 0  1/1/2023      Sunday  Morning (7AM-12PM)  Krista Kircanski
# 1  1/2/2023      Monday  Evening (5PM-10PM)      Kate Gilbert
# 2  1/2/2023      Monday  Evening (5PM-10PM)      Kate Gilbert
# 3  1/2/2023      Monday  Evening (5PM-10PM)     Kathryn Nolan
# 4  1/2/2023      Monday  Morning (7AM-12PM)       Leah Santos
#
#        Pickup Location  Dropoff Location            Fill Type
# 0  GO - Grocery Outlet               BOK    Rescued Groceries
# 1         Grocery FILL               BOK  Purchased Groceries
# 2         Grocery FILL  DS - DiSilvestro  Purchased Groceries
# 3         Grocery FILL               BOK  Purchased Groceries
# 4         Grocery FILL           Mifflin  Purchased Groceries

# %%
# Convert Date to Datetime Object
# Then create the DataFrame
def convert_to_date(x):
    return pd.to_datetime(x).date()

df_dates['Date'] = df_dates['Date'].apply(convert_to_date)

# Display the DataFrame
df_dates
# Out:
#             Date Day of Week           Time of Day                  Name  \
# 0     2023-01-01      Sunday    Morning (7AM-12PM)      Krista Kircanski
# 1     2023-01-02      Monday    Evening (5PM-10PM)          Kate Gilbert
# 2     2023-01-02      Monday    Evening (5PM-10PM)          Kate Gilbert
# 3     2023-01-02      Monday    Evening (5PM-10PM)         Kathryn Nolan
# 4     2023-01-02      Monday    Morning (7AM-12PM)           Leah Santos
# ...          ...         ...                   ...                   ...
# 3057  2023-12-31      Sunday    Evening (5PM-10PM)        Maulik Kadakia
# 3058  2023-12-31      Sunday    Evening (5PM-10PM)        Maulik Kadakia
# 3059  2023-12-31      Sunday    Evening (5PM-10PM)        Maulik Kadakia
# 3060  2023-12-31      Sunday    Evening (5PM-10PM)        Maulik Kadakia
# 3061  2023-12-31      Sunday  Afternoon (12PM-5PM)  Benjamin Miller - PK
#
#             Pickup Location       Dropoff Location            Fill Type  Hour  \
# 0       GO - Grocery Outlet                    BOK    Rescued Groceries     0
# 1              Grocery FILL                    BOK  Purchased Groceries     0
# 2              Grocery FILL       DS - DiSilvestro  Purchased Groceries     0
# 3              Grocery FILL                    BOK  Purchased Groceries     0
# 4              Grocery FILL                Mifflin  Purchased Groceries     0
# ...                     ...                    ...                  ...   ...
# 3057           Grocery FILL                    BOK  Purchased Groceries     0
# 3058           Grocery FILL                Mifflin  Purchased Groceries     0
# 3059           Grocery FILL       DS - DiSilvestro  Purchased Groceries     0
# 3060           Grocery FILL  PK - People's Kitchen  Purchased Groceries     0
# 3061  PK - People's Kitchen  PK - People's Kitchen                Meals     0
#
#          Month Time_of_Day
# 0      January        None
# 1      January        None
# 2      January        None
# 3      January        None
# 4      January        None
# ...        ...         ...
# 3057  December        None
# 3058  December        None
# 3059  December        None
# 3060  December        None
# 3061  December        None
#
# [3062 rows x 10 columns]

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Define the start and end dates for the year
start_date = pd.to_datetime('2023-01-01')
end_date = pd.to_datetime('2023-12-31')

# Iterate through the dates
for current_date in pd.date_range(start=start_date, end=end_date):
    # Filter for Morning donations
    morning_donations = df_dates.loc[(df_dates["Time of Day"] == "Morning (7AM-12PM)") & 
                                     (df_dates["Date"].dt.date == current_date.date())]
    
    # Filter for Afternoon donations
    afternoon_donations = df_dates.loc[(df_dates["Time of Day"] == "Afternoon (12PM-5PM)") & 
                                       (df_dates["Date"].dt.date == current_date.date())]
    
    # Filter for Evening donations
    evening_donations = df_dates.loc[(df_dates["Time of Day"] == "Evening (5PM-10PM)") & 
                                     (df_dates["Date"].dt.date == current_date.date())]
    
    # Print the number of donations for each time of day
    print(f"Date: {current_date.date()}")
    print(f"Morning Donations: {morning_donations.shape[0]}")
    print(f"Afternoon Donations: {afternoon_donations.shape[0]}")
    print(f"Evening Donations: {evening_donations.shape[0]}")
    print("---------------------------------------------")
# Out:
# Date: 2023-01-01
# Morning Donations: 1
# Afternoon Donations: 0
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-01-02
# Morning Donations: 5
# Afternoon Donations: 0
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-01-03
# Morning Donations: 1
# Afternoon Donations: 0
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-01-04
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-01-05
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 6
# ---------------------------------------------
# Date: 2023-01-06
# Morning Donations: 1
# Afternoon Donations: 0
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-01-07
# Morning Donations: 1
# Afternoon Donations: 0
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-01-08
# Morning Donations: 5
# Afternoon Donations: 0
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-01-09
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-01-10
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-01-11
# Morning Donations: 4
# Afternoon Donations: 0
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-01-12
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-01-13
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-01-14
# Morning Donations: 2
# Afternoon Donations: 0
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-01-15
# Morning Donations: 6
# Afternoon Donations: 0
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-01-16
# Morning Donations: 1
# Afternoon Donations: 0
# Evening Donations: 8
# ---------------------------------------------
# Date: 2023-01-17
# Morning Donations: 1
# Afternoon Donations: 0
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-01-18
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-01-19
# Morning Donations: 2
# Afternoon Donations: 0
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-01-20
# Morning Donations: 2
# Afternoon Donations: 0
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-01-21
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-01-22
# Morning Donations: 5
# Afternoon Donations: 0
# Evening Donations: 5
# ---------------------------------------------
# Date: 2023-01-23
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 8
# ---------------------------------------------
# Date: 2023-01-24
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-01-25
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 6
# ---------------------------------------------
# Date: 2023-01-26
# Morning Donations: 4
# Afternoon Donations: 0
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-01-27
# Morning Donations: 4
# Afternoon Donations: 0
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-01-28
# Morning Donations: 8
# Afternoon Donations: 0
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-01-29
# Morning Donations: 6
# Afternoon Donations: 0
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-01-30
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-01-31
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 7
# ---------------------------------------------
# Date: 2023-02-01
# Morning Donations: 2
# Afternoon Donations: 2
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-02-02
# Morning Donations: 4
# Afternoon Donations: 3
# Evening Donations: 6
# ---------------------------------------------
# Date: 2023-02-03
# Morning Donations: 0
# Afternoon Donations: 2
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-02-04
# Morning Donations: 6
# Afternoon Donations: 8
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-02-05
# Morning Donations: 5
# Afternoon Donations: 6
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-02-06
# Morning Donations: 0
# Afternoon Donations: 2
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-02-07
# Morning Donations: 3
# Afternoon Donations: 4
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-02-08
# Morning Donations: 5
# Afternoon Donations: 1
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-02-09
# Morning Donations: 5
# Afternoon Donations: 8
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-02-10
# Morning Donations: 1
# Afternoon Donations: 4
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-02-11
# Morning Donations: 1
# Afternoon Donations: 10
# Evening Donations: 5
# ---------------------------------------------
# Date: 2023-02-12
# Morning Donations: 5
# Afternoon Donations: 1
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-02-13
# Morning Donations: 0
# Afternoon Donations: 1
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-02-14
# Morning Donations: 2
# Afternoon Donations: 1
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-02-15
# Morning Donations: 7
# Afternoon Donations: 7
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-02-16
# Morning Donations: 3
# Afternoon Donations: 1
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-02-17
# Morning Donations: 0
# Afternoon Donations: 1
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-02-18
# Morning Donations: 6
# Afternoon Donations: 5
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-02-19
# Morning Donations: 6
# Afternoon Donations: 4
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-02-20
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-02-21
# Morning Donations: 1
# Afternoon Donations: 6
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-02-22
# Morning Donations: 4
# Afternoon Donations: 3
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-02-23
# Morning Donations: 1
# Afternoon Donations: 2
# Evening Donations: 5
# ---------------------------------------------
# Date: 2023-02-24
# Morning Donations: 4
# Afternoon Donations: 2
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-02-25
# Morning Donations: 5
# Afternoon Donations: 2
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-02-26
# Morning Donations: 5
# Afternoon Donations: 1
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-02-27
# Morning Donations: 0
# Afternoon Donations: 2
# Evening Donations: 5
# ---------------------------------------------
# Date: 2023-02-28
# Morning Donations: 0
# Afternoon Donations: 5
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-03-01
# Morning Donations: 2
# Afternoon Donations: 3
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-03-02
# Morning Donations: 1
# Afternoon Donations: 0
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-03-03
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-03-04
# Morning Donations: 7
# Afternoon Donations: 1
# Evening Donations: 5
# ---------------------------------------------
# Date: 2023-03-05
# Morning Donations: 6
# Afternoon Donations: 1
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-03-06
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-03-07
# Morning Donations: 2
# Afternoon Donations: 2
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-03-08
# Morning Donations: 3
# Afternoon Donations: 4
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-03-09
# Morning Donations: 3
# Afternoon Donations: 0
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-03-10
# Morning Donations: 0
# Afternoon Donations: 1
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-03-11
# Morning Donations: 4
# Afternoon Donations: 0
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-03-12
# Morning Donations: 1
# Afternoon Donations: 6
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-03-13
# Morning Donations: 0
# Afternoon Donations: 1
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-03-14
# Morning Donations: 0
# Afternoon Donations: 0
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-03-15
# Morning Donations: 0
# Afternoon Donations: 3
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-03-16
# Morning Donations: 0
# Afternoon Donations: 4
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-03-17
# Morning Donations: 1
# Afternoon Donations: 0
# Evening Donations: 5
# ---------------------------------------------
# Date: 2023-03-18
# Morning Donations: 3
# Afternoon Donations: 5
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-03-19
# Morning Donations: 5
# Afternoon Donations: 1
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-03-20
# Morning Donations: 0
# Afternoon Donations: 1
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-03-21
# Morning Donations: 0
# Afternoon Donations: 3
# Evening Donations: 3
# ---------------------------------------------
# Date: 2023-03-22
# Morning Donations: 1
# Afternoon Donations: 4
# Evening Donations: 2
# ---------------------------------------------
# Date: 2023-03-23
# Morning Donations: 0
# Afternoon Donations: 4
# Evening Donations: 5
# ---------------------------------------------
# Date: 2023-03-24
# Morning Donations: 0
# Afternoon Donations: 2
# Evening Donations: 5
# ---------------------------------------------
# Date: 2023-03-25
# Morning Donations: 4
# Afternoon Donations: 2
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-03-26
# Morning Donations: 5
# Afternoon Donations: 1
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-03-27
# Morning Donations: 0
# Afternoon Donations: 1
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-12-26
# Morning Donations: 0
# Afternoon Donations: 6
# Evening Donations: 1
# ---------------------------------------------
# Date: 2023-12-27
# Morning Donations: 0
# Afternoon Donations: 7
# Evening Donations: 4
# ---------------------------------------------
# Date: 2023-12-28
# Morning Donations: 3
# Afternoon Donations: 2
# Evening Donations: 7
# ---------------------------------------------
# Date: 2023-12-29
# Morning Donations: 0
# Afternoon Donations: 3
# Evening Donations: 8
# ---------------------------------------------
# Date: 2023-12-30
# Morning Donations: 2
# Afternoon Donations: 1
# Evening Donations: 0
# ---------------------------------------------
# Date: 2023-12-31
# Morning Donations: 2
# Afternoon Donations: 2
# Evening Donations: 4
# ---------------------------------------------

# %% [markdown]
# ## Line graph for January

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for January 2023
january_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 1)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = january_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in January 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
# Show the figure
plt.show()

# %% [markdown]
# ## Line graph for February

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for February 2023
february_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 2)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = february_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in February 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for March

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for March 2023
march_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 3)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = march_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in March 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for April

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for April 2023
april_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 4)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = april_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in April 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for May

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for May 2023
may_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 5)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = may_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in May 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for June

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for June 2023
june_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 6)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = june_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in June 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for July

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for July 2023
july_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 7)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = july_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in July 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for August

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for August 2023
august_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 8)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = august_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in August 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for September

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for September 2023
september_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 9)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = september_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in September 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for October

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for October 2023
october_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 10)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = october_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in October 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for November

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for November 2023
november_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 11)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = november_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in November 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line graph for December

# %%
# Convert the "Date" column to datetime objects
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Filter the DataFrame for December 2023
december_data = df_dates.loc[(df_dates['Date'].dt.year == 2023) & (df_dates['Date'].dt.month == 12)]

# Group the data by date and time of day and count the number of donations for each group
daily_donations = december_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(10, 6))
daily_donations.plot(kind='line', marker='o', linestyle='-')
plt.title('Donations by Time of Day in December 2023')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time of Day')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Make the interactive interface here

# %%
# Create interactive dropdown menu
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact, widgets

def plot_donations_by_month(year, month):
    # Filter the DataFrame for the selected month and year
    monthly_data = df_dates.loc[(df_dates['Date'].dt.year == year) & (df_dates['Date'].dt.month == month)]
    
    # Group the data by date and time of day and count the number of donations for each group
    monthly_donations = monthly_data.groupby(['Date', 'Time of Day']).size().unstack(fill_value=0)
    
    # Plot the data
    plt.figure(figsize=(10, 6))
    monthly_donations.plot(kind='line', marker='o', linestyle='-')
    plt.title(f'Donations by Time of Day in {month}/{year}')
    plt.xlabel('Date')
    plt.ylabel('Number of Donations')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.legend(title='Time of Day')
    plt.tight_layout()
    # Show the figure
    plt.show()

# Define the options for the dropdown menu
years = [2023]  # Add more years if needed
months = range(1, 13)  # January to December

# Create interactive dropdown menus
interact(plot_donations_by_month, year=widgets.Dropdown(options=years, description='Year:'),
         month=widgets.Dropdown(options=months, description='Month:'))
# Out:
# interactive(children=(Dropdown(description='Year:', options=(2023,), value=2023), Dropdown(description='Month:…
# <function __main__.plot_donations_by_month(year, month)>
